# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# df=pd.read_csv("C:/Users/MMC/Downloads/Dengue_Disease.csv")
# df=pd.read_csv("C:\\Users\\MMC\\Downloads\\Dengue_Disease.csv")
df=pd.read_csv(r"C:\Users\MMC\Downloads\Dengue_Disease.csv")
df
# Out:
#       Age  Sex  Fever  Headache  Arthralgia  Myalgia  \
# 0      14    1      0         1           1        1
# 1      27    1      1         1           1        1
# 2      28    1      1         0           0        1
# 3      61    0      1         0           1        1
# 4      37    1      0         0           1        0
# ...   ...  ...    ...       ...         ...      ...
# 1635   37    0      1         1           1        1
# 1636   27    0      0         1           0        1
# 1637   23    0      0         0           1        1
# 1638   30    0      0         0           1        0
# 1639   30    0      1         0           1        1
#
#       Conjunctivitis or Pain behind eyes  Skin rash  Generalized weakness  \
# 0                                      0          1                     0
# 1                                      1          1                     1
# 2                                      0          1                     0
# ...

# %%
df.shape
# Out:
# (1640, 23)

# %%
#df.isnull().sum()

# %%
#df.info()

# %%
df.describe()
# Out:
#                Age          Sex        Fever     Headache   Arthralgia  \
# count  1640.000000  1640.000000  1640.000000  1640.000000  1640.000000
# mean     48.433537     0.495732     0.506098     0.489024     0.501829
# std      24.866977     0.500134     0.500115     0.500032     0.500149
# min       4.000000     0.000000     0.000000     0.000000     0.000000
# 25%      28.000000     0.000000     0.000000     0.000000     0.000000
# 50%      49.000000     0.000000     1.000000     0.000000     1.000000
# 75%      70.000000     1.000000     1.000000     1.000000     1.000000
# max      90.000000     1.000000     1.000000     1.000000     1.000000
#
#            Myalgia  Conjunctivitis or Pain behind eyes    Skin rash  \
# count  1640.000000                         1640.000000  1640.000000
# mean      0.478659                            0.492073     0.496951
# std       0.499697                            0.500090     0.500143
# ...

# %%
df.Dengue.value_counts()
# Out:
# Dengue
# 0    834
# 1    806
# Name: count, dtype: int64

# %%
df.Dengue.value_counts().plot(kind="bar", color=["brown", "yellow"])
plt.show()

# %%
# # create a correlation heatmap
# sns.heatmap(df.corr(),annot=True, cmap='terrain', linewidths=0.1)
# fig=plt.gcf()
# fig.set_size_inches(8,6)
# plt.show()
# sns.heatmap(df.corr(),annot=True,linewidths=2,cmap='terrain')
plt.figure(figsize=(22,22))
d = df.corr()
# sns.heatmap(d,annot=True,cmap= plt.cm.CMRmap_r)
sns.heatmap(d,annot=True,cmap= plt.cm.CMRmap_r)

plt.show()

# %%
#drop the less corelated coloums 
df2=df.drop(["Myalgia","Fever","Headache","Arthralgia","Generalized weakness","watery diarrhea", "Conjunctivitis or Pain behind eyes","coma","IgG","Ecchymosis","Convulsions",], axis = 1)
df2
# Out:
#       Age  Sex  Skin rash  Jaundice  Decrease of urine or anuria  \
# 0      14    1          1         0                            1
# 1      27    1          1         0                            0
# 2      28    1          1         1                            1
# 3      61    0          1         0                            0
# 4      37    1          1         1                            1
# ...   ...  ...        ...       ...                          ...
# 1635   37    0          1         0                            0
# 1636   27    0          0         1                            1
# 1637   23    0          1         1                            1
# 1638   30    0          0         1                            0
# 1639   30    0          1         1                            1
#
#       Abdominal pain  Vomiting  meningitis  \
# 0                  0         0           0
# 1                  1         0           0
# 2                  0         1           1
# ...

# %%
# df.d.plot(kind="bar", color=["brown", "yellow"])
# df2.plot(kind="bar", )

# plt.show()

# %%
X = df2.drop('Dengue',axis=1)
Y = df2['Dengue']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size= 0.2, random_state=101)

# %%
Y_train.value_counts()
# Out:
# Dengue
# 0    675
# 1    637
# Name: count, dtype: int64

# %%
Y_test.value_counts()
# Out:
# Dengue
# 1    169
# 0    159
# Name: count, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
#from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score
# dt=DecisionTreeClassifier(criterion= 'gini', min_samples_split= 100,max_depth=20,max_features='sqrt', splitter= 'best',max_leaf_nodes=10,random_state=42)
dt=DecisionTreeClassifier()
dt.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction=dt.predict(X_test)
accuracy_dt=accuracy_score(Y_test,prediction)*100
print("accuracy in DT=",accuracy_dt)
# Out:
# accuracy in DT= 50.609756097560975

# %%
print("Accuracy on training set: {:.3f}".format(dt.score(X_train, Y_train)))
print("Accuracy on test set: {:.3f}".format(dt.score(X_test, Y_test)))
# Out:
# Accuracy on training set: 0.998
# Accuracy on test set: 0.506

# %%
accuracy_score(prediction,Y_test)
# Out:
# 0.5060975609756098

# %%
from sklearn.ensemble import RandomForestClassifier
#dt=RandomForestClassifier(criterion= 'gini', min_samples_split= 100,max_depth=20,max_features='sqrt', splitter= 'best',max_leaf_nodes=10,random_state=42)

rf=RandomForestClassifier(criterion= 'gini', min_samples_split= 1000,max_leaf_nodes=10)
rf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(max_leaf_nodes=10, min_samples_split=1000)

# %%
prediction=rf.predict(X_test)
accuracy_rf=accuracy_score(Y_test,prediction)*100
print("accuracy of RF=",accuracy_rf)
# Out:
# accuracy of RF= 48.47560975609756

# %%
from sklearn.ensemble import GradientBoostingClassifier
dani=GradientBoostingClassifier( min_samples_split= 1000)
dani.fit(X_train,Y_train)
# Out:
# GradientBoostingClassifier(min_samples_split=1000)

# %%
prediction=dani.predict(X_test)
accuracy_dani=accuracy_score(Y_test,prediction)*100
print("accuracy of GBC",accuracy_dani)
# Out:
# accuracy of GBC 46.95121951219512

# %% [raw]
# #Prediction on only one set of data

# %% [markdown]
# #this is the multible 'yes' recoreds

# %%
# y=dt.predict([[14,1,1,0,1,0,0,0,1,0,0]]) #thsi actual ouput is 0 but given 1
y=dt.predict([[27,1,1,0,0,1,0,0,0,1,0]]) #this actual output is 0 and it will the answer also 0
y
# Out:
# C:\Users\MMC\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
#this is the multible 'no' recoreds

# %%
y = dt.predict([[37,1,1,1,1,0,1,0,1,0,0,]]) #thsi actual ouput is 1 but given 1
# y = dt.predict([[28,1,1,1,1,0,1,1,0,0,0]]) #thsi actual ouput is 1 but given 0

y
# Out:
# C:\Users\MMC\AppData\Local\Programs\Python\Python38\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
#completed
